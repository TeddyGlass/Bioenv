# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import umap

# %% [markdown]
# # Decomposition

# %% [markdown]
# ### DeepLoc

# %% [markdown]
# Language model

# %%
root = '../data/DeepLoc/'
f_names = [
    'DeepLocEmbedd_Albert_BFD.csv',
    'DeepLocEmbedd_BERT_BFD.csv',
    'DeepLocEmbedd_T5_BFD.csv',
    'DeepLocEmbedd_T5_FT.csv'
    ]

# load dataset
df = pd.read_csv(os.path.join(root, f_names[2]))

# processing
localization = df.iloc[:,1].unique().tolist()
localization_idxes = [np.array(df.iloc[:,1]==loc) for loc in localization]
# X = np.array()

# %%
df.iloc[:,3:]
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.001023  0.001064  0.029530  0.015261  0.023635 -0.046274  0.010815
# 1     0.044966 -0.036776 -0.036976 -0.016031 -0.021857 -0.035947 -0.067293
# 2    -0.109663  0.122908 -0.026915 -0.093383 -0.037754 -0.082086  0.005380
# 3    -0.050356  0.055189  0.035990 -0.044733  0.054742 -0.002285 -0.046872
# 4    -0.024892 -0.005205  0.022116 -0.023804 -0.028802 -0.020810 -0.057479
# ...        ...       ...       ...       ...       ...       ...       ...
# 8459  0.061955  0.045375 -0.045571 -0.036366 -0.039456 -0.084817 -0.150278
# 8460 -0.023149 -0.017185  0.028739 -0.006808  0.004747 -0.059887 -0.033981
# 8461 -0.097791  0.012732  0.028228  0.005766  0.023252 -0.052908 -0.058405
# 8462 -0.072091 -0.012041 -0.042315 -0.077019  0.024501 -0.021220 -0.088913
# 8463  0.056425  0.064430 -0.072781 -0.094640 -0.048743 -0.027244 -0.140820
#
# ...
